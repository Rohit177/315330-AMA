# %% [markdown]
# # **Practical No. 9: Train Test Split**
#
# >  **Title:** *Write program in python to split any dataset into train and tests sets*
#
# > **Domain:** Machine Learning
#  <br> **Technology:** Python
#
# > **Description:** Train-test split is a fundamental technique in machine learning used to evaluate a model’s performance by dividing a dataset into two subsets: a training set and a testing set. The training set is used to train the model, while the testing set is kept separate and used to assess how well the model generalizes to new, unseen data.
#
# > **Resource:**
# * https://medium.com/the-code-monster/split-a-dataset-into-train-and-test-datasets-using-sk-learn-acc7fd1802e0
#
# ---
# <center> </center>

# %% [markdown]
# ### Import Library

# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Import Dataset

# %%
url = 'https://raw.githubusercontent.com/kirenz/datasets/master/cars.csv'
df = pd.read_csv(url)
df.head()

# %% [markdown]
# ### Plot data

# %%
plt.scatter(df['Miles_per_Gallon'],df['Horsepower'])

# %% [markdown]
# ### Define X and Y

# %%
X = df[['Miles_per_Gallon','Cylinders']]
Y = df['Horsepower']

# %% [markdown]
# > Shape of X and y

# %%
print("Shape of X:", X.shape)
print("Shape of Y:", Y.shape)
# Out:
# Shape of X: (392, 2)
# Shape of Y: (392,)

# %% [markdown]
# ### Split into train test
# > test size 20%

# %%
x_train, x_test,y_train,y_test = train_test_split(X,Y,test_size =0.2)

# %% [markdown]
# > Shape of test train

# %%
print('x_train:', x_train.shape, 'y_train:', y_train.shape)
print('x_test: ', x_test.shape,  'y_test: ', y_test.shape)
# Out:
# x_train: (313, 2) y_train: (313,)
# x_test:  (79, 2) y_test:  (79,)
