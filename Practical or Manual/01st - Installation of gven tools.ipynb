# %% [markdown]
# ## **PPRACTICAL NO. 01: Installation**
#
# >  **Title:** *Install given Python IDE software and Python “scikit learn” for ML*
#
# > **Domain:** Artificial Intelligence and Machine Learning
#  <br> **Technology:** Python
#
# > **Description:** Python is a powerful, easy-to-learn programming language widely used in data science and machine learning; Jupyter is an interactive web-based environment that allows users to write, execute, and visualize Python code in a notebook format; and Scikit-learn is a library that provides simple and efficient tools for data mining, machine learning, and data analysis.
#
#
# > **Resource:**
#   Cheat Sheet for Google Colab: https://colab.research.google.com/github/Tanu-N-Prabhu/Python/blob/master/Cheat_sheet_for_Google_Colab.ipynb
#
# <center> </center>

# %% [markdown]
# <br><br>

# %% [markdown]
# ---
# ### Python Installation Guide
# ---
#
# ##### Step-by-step instructions to install Python on Windows
#
# 1. **Download Python Installer**
#    - Go to the [official Python website](https://www.python.org/downloads/).
#    - Click on the latest version for Windows and download the executable installer.
#
# 2. **Run the Installer**
#    - Double-click the downloaded `.exe` file.
#    - ✅ **Important:** Check the box that says **"Add Python to PATH"**.
#    - Click **Install Now**.
#
# 3. **Verify Installation**
#    - Open **Command Prompt** and run:
#      ```sh
#      python --version
#      ```
#    - You should see the installed Python version.
#
# ---

# %% [markdown]
# <br><br>

# %% [markdown]
# ---
# ### Jupyter Notebook Installation Guide
# ---
#
# ##### Step-by-step instructions to install Jupyter Notebbok
#
# 1. **Prerequisites**
# - Python 3.7 or newer
# - pip (Python package installer)
#
# 2. **Install Scikit-Learn**
#    - Open **Command Prompt** and run:
#      ```sh
#      pip install notebook
#      ```
#
# 3. **Launch Jupyter Notebook**
#    - Open **Command Prompt** and run:
#      ```sh
#      jupyter notebook
#      ```
#      or
#      ```sh
#      python -m notebook
#      ```
#
#    - This command will open Jupyter Notebook in your default web browser.
#
# ---

# %% [markdown]
# <br><br>

# %% [markdown]
# ---
# ### Scikit Learn Installation Guide
# ---
#
# ##### Step-by-step instructions to install Sckit-Learn
#
# 1. **Prerequisites**
# - Python 3.7 or newer
# - pip (Python package installer)
#
# 2. **Install Scikit-Learn**
#    - Open **Command Prompt** and run:
#      ```sh
#      pip install scikit-learn
#      ```
#
# 3. **Verify Installation**
#    - Open **Command Prompt** and run:
#      ```sh
#      import sklearn
#       print(sklearn.__version__)
#
#      ```
#    - You should see the installed Python version.
#
# ---

# %% [markdown]
# <br><br>

# %% [markdown]
# ---
# ### **Scikit Learn usage throughout subject**
# ---
# > **Pre-defined methods:**
# * LogisticRegression()
# * KNeighbors()
# * DecisionTree()
# * RandomForest()
# * NaiveBayes() (GaussianNB, MultinomialNB, etc.)
# * LinearRegression()
# * KMeans()
# * PCA()
# * train_test_split()
# * classification_report()
# * confusion_matrix()
# * mean_squared_error()
# * r2_score()
# * MinMaxScaler()
# * LabelEncoder()
